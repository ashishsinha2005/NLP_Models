# %%
#semantic-search-in-python

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from transformers import AutoTokenizer, AutoModel
import torch
import ast
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import matplotlib.pyplot as plt
from tqdm import tqdm
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ashis\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ashis\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ashis\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Load the Excel file

df = pd.read_excel(r"data\\linkedin_job_posts_insights.xlsx")
# Initial data inspection

# %%
print("Shape:", df.shape)
print("Size:", df.size)
print("Columns:", df.columns)
print("Info:")
print(df.info())
print("Count of null values:\n", df.isnull().sum())
# Drop rows with null values
df_cleaned = df.dropna()
# Count after dropping nulls
print("Count after dropping null values:\n", df_cleaned.isnull().sum())
# Out:
# Shape: (31597, 9)
# Size: 284373
# Columns: Index(['job_title', 'company_name', 'location', 'hiring_status', 'date',
#        'seniority_level', 'job_function', 'employment_type', 'industry'],
#       dtype='object')
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31597 entries, 0 to 31596
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_title        31571 non-null  object
#  1   company_name     30657 non-null  object
#  2   location         31588 non-null  object
#  3   hiring_status    31597 non-null  object
#  4   date             31597 non-null  datetime64[ns]
#  5   seniority_level  30289 non-null  object
#  6   job_function     30007 non-null  object
#  7   employment_type  30006 non-null  object
#  8   industry         29586 non-null  object
# dtypes: datetime64[ns](1), object(8)
# memory usage: 2.2+ MB
# None
# Count of null values:
#  job_title            26
# company_name        940
# location              9
# hiring_status         0
# date                  0
# seniority_level    1308
# job_function       1590
# employment_type    1591
# industry           2011
# dtype: int64
# Count after dropping null values:
#  job_title          0
# company_name       0
# location           0
# hiring_status      0
# date               0
# seniority_level    0
# job_function       0
# employment_type    0
# industry           0
# dtype: int64

# %%
def preprocess_text(text):
    text = str(text).lower()
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return ' '.join(tokens)
def generate_embedding(text, tokenizer, model):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).numpy()
def extract_relevant_sentences(summary, query_embedding, tokenizer, model, k=2):
    sentences = summary.split(".")
    sentence_embeddings = [generate_embedding(sentence, tokenizer, model) for sentence in sentences]
    similarities = [cosine_similarity(query_embedding.reshape(1, -1),sentence_embedding.reshape(1, -1))[0, 0] for sentence_embedding in sentence_embeddings]
    top_k_indices = np.argsort(similarities)[-k:]
    return [sentences[index] for index in top_k_indices]
def search_authors_and_relevant_parts(df, query, tokenizer, model, n=3, k=2):
    query_embedding = generate_embedding(query, tokenizer, model)
    df["similarity"] = df["embedding"].apply(lambda x: cosine_similarity(x.reshape(1, -1), query_embedding.reshape(1, -1))[0, 0])
    top_n_results = df.sort_values("similarity", ascending=False).head(n)
    for _, row in top_n_results.iterrows():
        relevant_parts = extract_relevant_sentences(row["summary"],query_embedding, tokenizer, model, k)
        print(f"Job Title: {row['job_title']} (similarity: {row['similarity']:4f})")
        print(f"Relevant parts: {'.'.join(relevant_parts)}...")

# %%
model_name = "sentence-transformers/paraphrase-MiniLM-L6-v2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# C:\Users\ashis\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:159: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\ashis\.cache\huggingface\hub\models--sentence-transformers--paraphrase-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# C:\Users\ashis\anaconda3\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]

# %%
# Create a summary column with all relevant metadata concatenated
df_cleaned.loc[:, 'summary'] = df_cleaned.apply(
lambda x: f"{x['job_title']} {x['company_name']} {x['location']}{x['hiring_status']} {x['date']} {x['seniority_level']} {x['job_function']}{x['employment_type']} {x['industry']}", axis=1)
# Preprocess the summary text
df_cleaned.loc[:, "preprocessed_summary"] = df_cleaned["summary"].apply(preprocess_text)
# Generate embeddings and save them, avoiding comma errors
embeddings = []
for summary in tqdm(df_cleaned["preprocessed_summary"], desc="Generatingembeddings"):
    embedding = generate_embedding(summary, tokenizer, model)
    embeddings.append(embedding)
# Convert embeddings to a format that can be saved without comma errors
df_cleaned.loc[:, "embedding"] = embeddings
df_cleaned.loc[:, "embedding"] = df_cleaned["embedding"].apply(lambda x: ', '.join(map(str, x[0])))
# Save the DataFrame with embeddings to a CSV file
df_cleaned.to_csv("summaries_with_embeddings.csv", index=False)
# Out:
# C:\Users\ashis\AppData\Local\Temp\ipykernel_6916\1191123570.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned.loc[:, 'summary'] = df_cleaned.apply(
# C:\Users\ashis\AppData\Local\Temp\ipykernel_6916\1191123570.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned.loc[:, "preprocessed_summary"] = df_cleaned["summary"].apply(preprocess_text)
# Generatingembeddings: 100%|██████████████████████████████████████████████████████████████████████████████████| 27972/27972 [04:49<00:00, 96.79it/s]
# C:\Users\ashis\AppData\Local\Temp\ipykernel_6916\1191123570.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned.loc[:, "embedding"] = embeddings

# %%
import pandas as pd
import numpy as np
# Load the CSV file
df_with_embeddings = pd.read_csv("summaries_with_embeddings.csv")
# Convert the embeddings from strings back to numpy arrays
df_with_embeddings["embedding"] = df_with_embeddings["embedding"].apply(
lambda x: np.array([float(num) for num in x.split(', ')])
)

# %%
from sklearn.metrics.pairwise import cosine_similarity
def search(query, df, tokenizer, model, top_n=5):
    # Preprocess the query
    preprocessed_query = preprocess_text(query)
    # Generate the embedding for the query
    query_embedding = generate_embedding(preprocessed_query, tokenizer,model)[0]
    # Compute cosine similarity between the query embedding and the job embeddings
    similarities = cosine_similarity([query_embedding], list(df["embedding"]))
    # Add similarity scores to the DataFrame
    df["similarity_score"] = similarities[0]
    # Get the top N most similar results
    top_n_indices = np.argsort(similarities[0])[-top_n:][::-1]
    top_n_results = df.iloc[top_n_indices]
    return top_n_results

# %%
while True:
    # Ask the user for input query
    query = input("Enter your query (or 'exit' to quit): ")
    # Check if the user wants to exit
    if query.lower() == 'exit':
        print("Exiting...")
        break
    # Perform semantic search using the search function
    results = search(query, df_with_embeddings, tokenizer, model)
# Display the top results
print(f"\nTop results for '{query}':")
for index, row in results.iterrows():
    print(f"Job Title: {row['job_title']}")
    print(f"Company: {row['company_name']}")
    print(f"Location: {row['location']}")
    print(f"Similarity Score: {row['similarity_score']:.4f}")
    print("-------------------------")
# Out:
# Enter your query (or 'exit' to quit):  Hey buddy help me find jobs related to Big Data Analytics in India country
# Enter your query (or 'exit' to quit):  exit
# Exiting...
#
# Top results for 'exit':
# Job Title: Interesting Job Opportunity: Senior Analyst - Data Science
# Company: AOS
# Location: Kolkata, West Bengal, India
# Similarity Score: 0.6424
# -------------------------
# Job Title: Interesting Job Opportunity: Senior Analyst - R/SQL/Python
# Company: AOS
# Location: Warangal, Telangana, India
# Similarity Score: 0.6403
# -------------------------
# Job Title: Big Data Engineer - E4504
# Company: Nisum
# Location: Hyderabad, Telangana, India
# Similarity Score: 0.6322
# -------------------------
# Job Title: Interesting Job Opportunity: Full Stack Developer - React.js/Node.js
# Company: Justdial
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.6150
# -------------------------
# Job Title: Interesting Job Opportunity: Full Stack Developer - React.js/Node.js
# Company: Justdial
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.6150
# -------------------------

# %%
def search(query, df, tokenizer, model, top_n=5):
    # Preprocess the query
    preprocessed_query = preprocess_text(query)
    # Generate the embedding for the query
    query_embedding = generate_embedding(preprocessed_query, tokenizer,model)[0]
    # Compute cosine similarity between the query embedding and the job embeddings
    similarities = cosine_similarity([query_embedding], list(df["embedding"]))
    # Add similarity scores to the DataFrame
    df["similarity_score"] = similarities[0]
# Get the top N most similar results
    top_n_indices = np.argsort(similarities[0])[-top_n:][::-1]
    top_n_results = df.iloc[top_n_indices]
    return top_n_results

# %%
while True:
    query = input("Enter your query (or 'exit' to quit): ").strip().lower()
    if query == 'exit':
        print("Exiting...")
        break
    if query:
        results = search(query, df_with_embeddings, tokenizer, model)
        if not results.empty:
            print(f"Top results for '{query}':")
            for index, result in results.iterrows():
                print(f"Job Title: {result['job_title']}")
                print(f"Company: {result['company_name']}")
                print(f"Location: {result['location']}")
                print(f"Similarity Score: {result['similarity_score']:.4f}")
                print("-------------------------")
        else:
            print("No results found.")
    else:
        print("Please enter a valid query.")
# Out:
# Enter your query (or 'exit' to quit):   Hey buddy , How are you? Can you help me find Data Scientist role . Also Data Analyst will also be fine.
# Top results for 'hey buddy , how are you? can you help me find data scientist role . also data analyst will also be fine.':
# Job Title: Lead Data Scientist
# Company: Correlate Resources
# Location: Melbourne, Victoria, Australia
# Similarity Score: 0.6154
# -------------------------
# Job Title: Lead Data Scientist
# Company: Correlate Resources
# Location: Melbourne, Victoria, Australia
# Similarity Score: 0.6154
# -------------------------
# Job Title: Lead Data Scientist
# Company: Correlate Resources
# Location: Melbourne, Victoria, Australia
# Similarity Score: 0.6154
# -------------------------
# Job Title: Lead Data Scientist
# Company: Correlate Resources
# Location: Melbourne, Victoria, Australia
# Similarity Score: 0.6039
# -------------------------
# Job Title: Lead Data Scientist
# Company: Correlate Resources
# Location: Melbourne, Victoria, Australia
# Similarity Score: 0.6039
# -------------------------
# Enter your query (or 'exit' to quit):  exit
# Exiting...

# %%
from sklearn.metrics.pairwise import cosine_similarity
def search(query, df, tokenizer, model, threshold=0.5):
    # Preprocess the query
    preprocessed_query = preprocess_text(query)
    # Generate the embedding for the query
    query_embedding = generate_embedding(preprocessed_query, tokenizer,model)[0]
    # Compute cosine similarity between the query embedding and the job␣↪embeddings
    similarities = cosine_similarity([query_embedding], list(df["embedding"]))
    # Add similarity scores to the DataFrame
    df["similarity_score"] = similarities[0]
    # Filter results based on the similarity score threshold
    matching_results = df[df["similarity_score"] >= threshold]
    # Sort results by similarity score in descending order
    matching_results = matching_results.sort_values(by="similarity_score",ascending=False)
    return matching_results

# %%
while True:
    query = input("Enter your query (or 'exit' to quit): ").strip().lower()
    if query == 'exit':
        print("Exiting...")
        break
    if query:
        results = search(query, df_with_embeddings, tokenizer, model,threshold=0.5)
        if not results.empty:
            print(f"Matching results for '{query}':")
            for index, result in results.iterrows():
                print(f"Job Title: {result['job_title']}")
                print(f"Company: {result['company_name']}")
                print(f"Location: {result['location']}")
                print(f"Similarity Score: {result['similarity_score']:.4f}")
                print("-------------------------")
            else:
                print("No results found.")
    else:
        print("Please enter a valid query.")
# Out:
# Enter your query (or 'exit' to quit):  Hey buddy i am looking for data analyst and data scientist role could you help me find roles in India
# Matching results for 'hey buddy i am looking for data analyst and data scientist role could you help me find roles in india':
# Job Title:
#
#         AI/ML Data Scientist
#
#
# Company:
#             Experfy
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.6197
# -------------------------
# Job Title: Interesting Job Opportunity: Senior Analyst - Data Science
# Company: AOS
# Location: Kolkata, West Bengal, India
# Similarity Score: 0.6116
# -------------------------
# Job Title: Lead Data Scientist
# Company: Correlate Resources
# Location: Melbourne, Victoria, Australia
# Similarity Score: 0.5996
# -------------------------
# Job Title: Lead Data Scientist
# Company: Correlate Resources
# Location: Melbourne, Victoria, Australia
# Similarity Score: 0.5996
# -------------------------
# Job Title: Lead Data Scientist
# Company: Correlate Resources
# Location: Melbourne, Victoria, Australia
# Similarity Score: 0.5996
# -------------------------
# Job Title: Researcher - Data Operations
# Company: Synaptic
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5981
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Response Informatics
#
# Location:
#             Delhi, India
#
# Similarity Score: 0.5950
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Wrackle
#
# Location:
#             Bengaluru North, Karnataka, India
#
# Similarity Score: 0.5936
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Acuity Knowledge Partners
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5896
# -------------------------
# Job Title: Interesting Job Opportunity: Senior Analyst - R/SQL/Python
# Company: AOS
# Location: Warangal, Telangana, India
# Similarity Score: 0.5882
# -------------------------
# Job Title: Lead/Senior Software Engineer - Backend (remote)
# Company: LeanHR
# Location: India
# Similarity Score: 0.5874
# -------------------------
# Job Title: Lead/Senior Software Engineer - Backend (remote)
# Company: LeanHR
# Location: India
# Similarity Score: 0.5874
# -------------------------
# Job Title: Lead/Senior Software Engineer - Backend (remote)
# Company: LeanHR
# Location: India
# Similarity Score: 0.5874
# -------------------------
# Job Title: Lead/Senior Software Engineer - Backend (remote)
# Company: LeanHR
# Location: India
# Similarity Score: 0.5874
# -------------------------
# Job Title: Lead/Senior Software Engineer - Backend (remote)
# Company: LeanHR
# Location: India
# Similarity Score: 0.5874
# -------------------------
# Job Title: Lead/Senior Software Engineer - Backend (remote)
# Company: LeanHR
# Location: India
# Similarity Score: 0.5874
# -------------------------
# Job Title: Lead/Senior Software Engineer - Backend (remote)
# Company: LeanHR
# Location: India
# Similarity Score: 0.5874
# -------------------------
# Job Title: Lead/Senior Software Engineer - Backend (remote)
# Company: LeanHR
# Location: India
# Similarity Score: 0.5874
# -------------------------
# Job Title:
#
#         Data Scientist III.
#
#
# Company:
#             InMobi
#
# Location:
#             Bangalore Urban, Karnataka, India
#
# Similarity Score: 0.5857
# -------------------------
# Job Title:
#
#         Data Scientist ( Computer Vision , NLP)- Immediate Joiners - Exp-2-4 years
#
#
# Company:
#             ValueLabs
#
# Location:
#             Hyderabad, Telangana, India
#
# Similarity Score: 0.5846
# -------------------------
# Job Title: Interesting Job Opportunity: Senior Research Analyst - Python/Visualization
# Company: Version Next Technologies Pvt. Ltd.
# Location: Hyderabad, Telangana, India
# Similarity Score: 0.5840
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             GreyB
#
# Location:
#             Chandigarh, India
#
# Similarity Score: 0.5828
# -------------------------
# Job Title:
#
#         Country HR Manager and HR Support
#
#
# Company:
#             RS Consulting
#
# Location:
#             Pimpri Chinchwad, Maharashtra, India
#
# Similarity Score: 0.5820
# -------------------------
# Job Title:
#
#         Data Scientist (Remote)
#
#
# Company:
#             codvo.ai
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5716
# -------------------------
# Job Title: Lead/Senior Software Engineer - Backend (remote)
# Company: LeanHR
# Location: India
# Similarity Score: 0.5701
# -------------------------
# Job Title: Lead/Senior Software Engineer - Backend (remote)
# Company: LeanHR
# Location: India
# Similarity Score: 0.5701
# -------------------------
# Job Title: CIEL/SEL/25220: Research Analyst Mumbai
# Company: CIEL HR
# Location: Mumbai, Maharashtra, India
# Similarity Score: 0.5700
# -------------------------
# Job Title: Backend Engineer (REMOTE OPPORTUNITY)
# Company: Qrata
# Location: India
# Similarity Score: 0.5688
# -------------------------
# Job Title: Backend Engineer (REMOTE OPPORTUNITY)
# Company: Qrata
# Location: India
# Similarity Score: 0.5688
# -------------------------
# Job Title: Backend Engineer (REMOTE OPPORTUNITY)
# Company: Qrata
# Location: India
# Similarity Score: 0.5688
# -------------------------
# Job Title: Backend Engineer (REMOTE OPPORTUNITY)
# Company: Qrata
# Location: India
# Similarity Score: 0.5688
# -------------------------
# Job Title: Backend Engineer (REMOTE OPPORTUNITY)
# Company: Qrata
# Location: India
# Similarity Score: 0.5688
# -------------------------
# Job Title: Backend Engineer (REMOTE OPPORTUNITY)
# Company: Qrata
# Location: India
# Similarity Score: 0.5688
# -------------------------
# Job Title: Backend Engineer (REMOTE OPPORTUNITY)
# Company: Qrata
# Location: India
# Similarity Score: 0.5688
# -------------------------
# Job Title: Backend Engineer (REMOTE OPPORTUNITY)
# Company: Qrata
# Location: India
# Similarity Score: 0.5688
# -------------------------
# Job Title: Backend Engineer (REMOTE OPPORTUNITY)
# Company: Qrata
# Location: India
# Similarity Score: 0.5688
# -------------------------
# Job Title: Lead Researcher
# Company: Admin Looks
# Location: Gurgaon, Haryana, India
# Similarity Score: 0.5687
# -------------------------
# Job Title: Research Analyst
# Company: Dimensions HRD Consultants
# Location: Mumbai, Maharashtra, India
# Similarity Score: 0.5685
# -------------------------
# Job Title: Lead Data Scientist
# Company: Correlate Resources
# Location: Melbourne, Victoria, Australia
# Similarity Score: 0.5683
# -------------------------
# Job Title: Lead Data Scientist
# Company: Correlate Resources
# Location: Melbourne, Victoria, Australia
# Similarity Score: 0.5683
# -------------------------
# Job Title: Lead Data Scientist
# Company: Correlate Resources
# Location: Melbourne, Victoria, Australia
# Similarity Score: 0.5681
# -------------------------
# Job Title:
#
#         Data Scientist (Remote)
#
#
# Company:
#             codvo.ai
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5677
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Wrackle
#
# Location:
#             Bengaluru North, Karnataka, India
#
# Similarity Score: 0.5658
# -------------------------
# Job Title:
#
#         Data Scientist (Early Joiners)
#
#
# Company:
#             Acuity Knowledge Partners
#
# Location:
#             Bangalore Urban, Karnataka, India
#
# Similarity Score: 0.5657
# -------------------------
# Job Title: Associate Researcher
# Company: Apporya Analytic Solutions LLP
# Location: Nagercoil, Tamil Nadu, India
# Similarity Score: 0.5655
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Acuity Knowledge Partners
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5640
# -------------------------
# Job Title:
#
#         Data Scientist (Remote)
#
#
# Company:
#             codvo.ai
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5613
# -------------------------
# Job Title:
#
#         Data Scientist - Remote (India)
#
#
# Company:
#             Aryng
#
# Location:
#             Kolkata, West Bengal, India
#
# Similarity Score: 0.5613
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             MasterMined Consulting
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5611
# -------------------------
# Job Title: Lead - Market Researcher [BFSI]
# Company: LeadSquared
# Location: Mumbai, Maharashtra, India
# Similarity Score: 0.5603
# -------------------------
# Job Title: Data Scientist (Graduate Role)
# Company: Gradfuel
# Location: London, England, United Kingdom
# Similarity Score: 0.5596
# -------------------------
# Job Title:
#
#         Solution Architect - Enterprise and Data Centre
#
#
# Company:
#             MBUZZ
#
# Location:
#             Kochi, Kerala, India
#
# Similarity Score: 0.5569
# -------------------------
# Job Title: Senior Research Manager � Analytics & Data Management
# Company: IDC
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5565
# -------------------------
# Job Title:
#
#         Data Scientist (Remote)
#
#
# Company:
#             Cambridge Technology (CT)
#
# Location:
#             Hyderabad, Telangana, India
#
# Similarity Score: 0.5552
# -------------------------
# Job Title: Deep Researcher
# Company: WorldQuant
# Location: Mumbai, Maharashtra, India
# Similarity Score: 0.5536
# -------------------------
# Job Title:
#
#         AI/ML Data Scientist
#
#
# Company:
#             Experfy
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5533
# -------------------------
# Job Title: User Researcher - Market Research [Qualitative
# Company: Vicara
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5529
# -------------------------
# Job Title: Analyst / Sr Analyst - Primary Research
# Company: Fave HR Solutions
# Location: Mumbai, Maharashtra, India
# Similarity Score: 0.5526
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             PlaySimple Games
#
# Location:
#             Bengaluru North, Karnataka, India
#
# Similarity Score: 0.5517
# -------------------------
# Job Title:
#
#         Data Science (AI) work from home job/internship at Statskew
#
#
# Company:
#             StatSkew
#
# Location:
#             India
#
# Similarity Score: 0.5514
# -------------------------
# Job Title:
#
#         Data Scientist (Remote)
#
#
# Company:
#             Cambridge Technology (CT)
#
# Location:
#             Hyderabad, Telangana, India
#
# Similarity Score: 0.5511
# -------------------------
# Job Title: Senior Data Scientist
# Company: Understanding Recruitment
# Location: London, England, United Kingdom
# Similarity Score: 0.5504
# -------------------------
# Job Title:
#
#         Data Scientist (Remote)
#
#
# Company:
#             codvo.ai
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5500
# -------------------------
# Job Title:
#
#         Data Scientist Jr. & Sr.
#
#
# Company:
#             thyssenkrupp
#
# Location:
#             Pune, Maharashtra, India
#
# Similarity Score: 0.5500
# -------------------------
# Job Title:
#
#         Data Scientist Jr. & Sr.
#
#
# Company:
#             thyssenkrupp
#
# Location:
#             Pune, Maharashtra, India
#
# Similarity Score: 0.5499
# -------------------------
# Job Title: Research Analyst (Executive Search), Bangalore (Ashok Nagar)
# Company: Talent Leads HR Solutions Pvt Ltd
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5493
# -------------------------
# Job Title: Big Data Engineer - E4504
# Company: Nisum
# Location: Hyderabad, Telangana, India
# Similarity Score: 0.5491
# -------------------------
# Job Title:
#
#         Data Scientist III.
#
#
# Company:
#             InMobi
#
# Location:
#             Bangalore Urban, Karnataka, India
#
# Similarity Score: 0.5484
# -------------------------
# Job Title:
#
#         Data Scientist - Precily AI
#
#
# Company:
#             Precily, Inc.
#
# Location:
#             Delhi, Delhi, India
#
# Similarity Score: 0.5479
# -------------------------
# Job Title:
#
#         Jr Frontend Developer
#
#
# Company:
#             Qrata
#
# Location:
#             Mumbai, Maharashtra, India
#
# Similarity Score: 0.5479
# -------------------------
# Job Title: Data Scientist, Supply Analyst
# Company: Let's Do This
# Location: London, England, United Kingdom
# Similarity Score: 0.5476
# -------------------------
# Job Title:
#
#         Jr Data Scientist
#
#
# Company:
#             Sciera, Inc.
#
# Location:
#             Chennai, Tamil Nadu, India
#
# Similarity Score: 0.5473
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             AB InBev
#
# Location:
#             Bangalore Urban, Karnataka, India
#
# Similarity Score: 0.5468
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Jubilant Ingrevia Limited
#
# Location:
#             Noida, Uttar Pradesh, India
#
# Similarity Score: 0.5467
# -------------------------
# Job Title: Lead Researcher - Research and Development - Chemicals/Paints
# Company: People Conexxions
# Location: Mumbai, Maharashtra, India
# Similarity Score: 0.5465
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             GreyB
#
# Location:
#             Chandigarh, India
#
# Similarity Score: 0.5464
# -------------------------
# Job Title:
#
#         Data Scientist 2
#
#
# Company:
#             Epsilon India
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5461
# -------------------------
# Job Title: Data Scientist (Graduate Role)
# Company: Gradfuel
# Location: London, England, United Kingdom
# Similarity Score: 0.5460
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Response Informatics
#
# Location:
#             Delhi, India
#
# Similarity Score: 0.5456
# -------------------------
# Job Title: Quantitative Researcher (INDIA)
# Company: Trexquant Investment LP
# Location: Gurugram, Haryana, India
# Similarity Score: 0.5431
# -------------------------
# Job Title: Interesting Job Opportunity: Webonise Lab - Senior Business Analyst
# Company: Webonise
# Location: Greater Kolkata Area
# Similarity Score: 0.5425
# -------------------------
# Job Title:
#
#         Data Scientist -1
#
#
# Company:
#             SatSure
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5423
# -------------------------
# Job Title: Senior Business Analyst - Operational Research
# Company: Changeleaders.in
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5420
# -------------------------
# Job Title: Data Scientist
# Company: Parker Lane
# Location: London, England, United Kingdom
# Similarity Score: 0.5404
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             ITC Infotech
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5401
# -------------------------
# Job Title:
#
#         Senior Data Scientist
#
#
# Company:
#             Licious
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5400
# -------------------------
# Job Title: Research Analyst
# Company: Synaptic
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5400
# -------------------------
# Job Title:
#
#         Data Scientist (Immediate Joiners only)
#
#
# Company:
#             Concentrix
#
# Location:
#             India
#
# Similarity Score: 0.5399
# -------------------------
# Job Title: Data Engineer
# Company: The Tech Galore
# Location: India
# Similarity Score: 0.5399
# -------------------------
# Job Title: Data Engineer
# Company: The Tech Galore
# Location: India
# Similarity Score: 0.5399
# -------------------------
# Job Title: Data Engineer
# Company: The Tech Galore
# Location: India
# Similarity Score: 0.5399
# -------------------------
# Job Title: Data Engineer
# Company: The Tech Galore
# Location: India
# Similarity Score: 0.5399
# -------------------------
# Job Title: Data Engineer
# Company: The Tech Galore
# Location: India
# Similarity Score: 0.5399
# -------------------------
# Job Title:
#
#         Human Resources (HR) Generalist
#
#
# Company:
#             Accoona Global
#
# Location:
#             Pune, Maharashtra, India
#
# Similarity Score: 0.5395
# -------------------------
# Job Title:
#
#         Data Scientist (Remote)
#
#
# Company:
#             codvo.ai
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5388
# -------------------------
# Job Title:
#
#         Data Scientist (Remote)
#
#
# Company:
#             codvo.ai
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5388
# -------------------------
# Job Title: Senior Consultant - Data Scientist
# Company: Infosys
# Location: Brisbane, Queensland, Australia
# Similarity Score: 0.5387
# -------------------------
# Job Title: Senior Consultant - Data Scientist
# Company: Infosys
# Location: Brisbane, Queensland, Australia
# Similarity Score: 0.5387
# -------------------------
# Job Title: Senior Consultant - Data Scientist
# Company: Infosys
# Location: Brisbane, Queensland, Australia
# Similarity Score: 0.5387
# -------------------------
# Job Title: Senior Consultant - Data Scientist
# Company: Infosys
# Location: Brisbane, Queensland, Australia
# Similarity Score: 0.5387
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             PayPal
#
# Location:
#             Chennai, Tamil Nadu, India
#
# Similarity Score: 0.5387
# -------------------------
# Job Title: Research Manager
# Company: Talentbes Executive Search
# Location: Gurgaon, Haryana, India
# Similarity Score: 0.5375
# -------------------------
# Job Title:
#
#         Software Engineer I (Frontend)
#
#
# Company:
#             Helpshift
#
# Location:
#             Pune, Maharashtra, India
#
# Similarity Score: 0.5372
# -------------------------
# Job Title:
#
#         Data Entry Operator
#
#
# Company:
#             Talent Zone Consultant
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5370
# -------------------------
# Job Title: Researcher (APAC/US/UK)
# Company: WhiteCrow Research
# Location: Mumbai, Maharashtra, India
# Similarity Score: 0.5366
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             ITC Infotech
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5357
# -------------------------
# Job Title:
#
#         Software Engineer I (Frontend)
#
#
# Company:
#             Helpshift
#
# Location:
#             Pune, Maharashtra, India
#
# Similarity Score: 0.5356
# -------------------------
# Job Title: Academic Researcher and Content Developer
# Company: Zucol Group
# Location: Indore, Madhya Pradesh, India
# Similarity Score: 0.5351
# -------------------------
# Job Title:
#
#         Data Science (AI) work from home job/internship at Statskew
#
#
# Company:
#             StatSkew
#
# Location:
#             India
#
# Similarity Score: 0.5348
# -------------------------
# Job Title: Frontend/Sr Engineer/Full Stack
# Company: Dimensions HRD Consultants
# Location: Bangalore Urban, Karnataka, India
# Similarity Score: 0.5344
# -------------------------
# Job Title: Frontend/Sr Engineer/Full Stack
# Company: Dimensions HRD Consultants
# Location: Bangalore Urban, Karnataka, India
# Similarity Score: 0.5344
# -------------------------
# Job Title:
#
#         Jr. Human Resources
#
#
# Company:
#             Digi Upaay Solutions Pvt Ltd
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5343
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             PlaySimple Games
#
# Location:
#             Bengaluru North, Karnataka, India
#
# Similarity Score: 0.5341
# -------------------------
# Job Title:
#
#         HR Functional Consultant
#
#
# Company:
#             Gentoro People Consulting
#
# Location:
#             Thane, Maharashtra, India
#
# Similarity Score: 0.5340
# -------------------------
# Job Title: Operations Research Analyst
# Company: Clearwater Analytics
# Location: Noida, Uttar Pradesh, India
# Similarity Score: 0.5332
# -------------------------
# Job Title: Frontend/Sr Engineer/Full Stack
# Company: Dimensions HRD Consultants
# Location: Bangalore Urban, Karnataka, India
# Similarity Score: 0.5327
# -------------------------
# Job Title: Frontend/Sr Engineer/Full Stack
# Company: Dimensions HRD Consultants
# Location: Bangalore Urban, Karnataka, India
# Similarity Score: 0.5327
# -------------------------
# Job Title: Frontend/Sr Engineer/Full Stack
# Company: Dimensions HRD Consultants
# Location: Bangalore Urban, Karnataka, India
# Similarity Score: 0.5327
# -------------------------
# Job Title: Frontend/Sr Engineer/Full Stack
# Company: Dimensions HRD Consultants
# Location: Bangalore Urban, Karnataka, India
# Similarity Score: 0.5327
# -------------------------
# Job Title:
#
#         Data Scientist -1
#
#
# Company:
#             SatSure
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5324
# -------------------------
# Job Title:
#
#         Web Developer
#
#
# Company:
#             Datastack Technologies
#
# Location:
#             Pune, Maharashtra, India
#
# Similarity Score: 0.5322
# -------------------------
# Job Title: Viz Developer
# Company: Gramener
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5317
# -------------------------
# Job Title:
#
#         HUMAN RESOURCE
#
#
# Company:
#             CareerMatch
#
# Location:
#             India
#
# Similarity Score: 0.5311
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Capgemini
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5306
# -------------------------
# Job Title: Associate/Sr Content writer
# Company: Quantzig
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5304
# -------------------------
# Job Title: Associate/Sr Content writer
# Company: Quantzig
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5304
# -------------------------
# Job Title: Associate/Sr Content writer
# Company: Quantzig
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5304
# -------------------------
# Job Title: Associate/Sr Content writer
# Company: Quantzig
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5304
# -------------------------
# Job Title: Sr Research Analyst II
# Company: S&P Global
# Location: Noida, Uttar Pradesh, India
# Similarity Score: 0.5301
# -------------------------
# Job Title: Data Scientist (Python, Django)
# Company: Talent
# Location: Melbourne, Victoria, Australia
# Similarity Score: 0.5297
# -------------------------
# Job Title: Data Scientist (Python, Django)
# Company: Talent
# Location: Melbourne, Victoria, Australia
# Similarity Score: 0.5297
# -------------------------
# Job Title: Data Scientist (Python, Django)
# Company: Talent
# Location: Melbourne, Victoria, Australia
# Similarity Score: 0.5297
# -------------------------
# Job Title: Data Scientist (Python, Django)
# Company: Talent
# Location: Melbourne, Victoria, Australia
# Similarity Score: 0.5297
# -------------------------
# Job Title: Content Roles - Expressions of Interest
# Company: IE
# Location: Melbourne, Victoria, Australia
# Similarity Score: 0.5297
# -------------------------
# Job Title: Content Writer
# Company: edge CRM - Your Strategic Growth Partner.
# Location: Mumbai, Maharashtra, India
# Similarity Score: 0.5294
# -------------------------
# Job Title: Senior Golang Engineer (India)
# Company: Persistence Labs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5293
# -------------------------
# Job Title: Senior Golang Engineer (India)
# Company: Persistence Labs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5293
# -------------------------
# Job Title: Senior Golang Engineer (India)
# Company: Persistence Labs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5293
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             TVS Next
#
# Location:
#             Chennai, Tamil Nadu, India
#
# Similarity Score: 0.5286
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             PlaySimple Games
#
# Location:
#             Bengaluru North, Karnataka, India
#
# Similarity Score: 0.5283
# -------------------------
# Job Title: JUNIOR DATA SCIENTIST & ANALYST PLACEMENT - 2024 INTAKE
# Company: Medialab Group
# Location: London, England, United Kingdom
# Similarity Score: 0.5280
# -------------------------
# Job Title: Team Lead Research Analyst (Due Dilligence)
# Company: Ameriprise Financial Services, LLC
# Location: Gurugram, Haryana, India
# Similarity Score: 0.5280
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             MasterMined Consulting
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5279
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             AB InBev
#
# Location:
#             Bangalore Urban, Karnataka, India
#
# Similarity Score: 0.5279
# -------------------------
# Job Title:
#
#         Associate Data Scientist
#
#
# Company:
#             AB InBev
#
# Location:
#             Greater Bengaluru Area
#
# Similarity Score: 0.5277
# -------------------------
# Job Title: Research Analyst/Content Creator - Education
# Company: HR Consultancy
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5275
# -------------------------
# Job Title:
#
#         Lead Data Scientist
#
#
# Company:
#             Spinny
#
# Location:
#             Gurugram, Haryana, India
#
# Similarity Score: 0.5274
# -------------------------
# Job Title:
#
#         Data Scientist (Immediate Joiners only)
#
#
# Company:
#             Concentrix
#
# Location:
#             India
#
# Similarity Score: 0.5274
# -------------------------
# Job Title:
#
#         Data Scientist (Immediate Joiners only)
#
#
# Company:
#             Concentrix
#
# Location:
#             India
#
# Similarity Score: 0.5274
# -------------------------
# Job Title: Senior Research Associate (Mumbai)
# Company: Visible Alpha
# Location: Mumbai, Maharashtra, India
# Similarity Score: 0.5273
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             OneLabs
#
# Location:
#             Delhi, Delhi, India
#
# Similarity Score: 0.5271
# -------------------------
# Job Title:
#
#         Data Scientist - Precily AI
#
#
# Company:
#             Precily, Inc.
#
# Location:
#             Delhi, Delhi, India
#
# Similarity Score: 0.5271
# -------------------------
# Job Title: Senior DevOps Engineer
# Company: Web3Auth
# Location: Akuhaito, Nagaland, India
# Similarity Score: 0.5267
# -------------------------
# Job Title: Senior DevOps Engineer
# Company: Web3Auth
# Location: Akuhaito, Nagaland, India
# Similarity Score: 0.5267
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Joveo
#
# Location:
#             Bangalore Urban, Karnataka, India
#
# Similarity Score: 0.5267
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             EXL
#
# Location:
#             Gurugram, Haryana, India
#
# Similarity Score: 0.5266
# -------------------------
# Job Title: Data Scientist Level 5
# Company: Whizdom Recruitment
# Location: Canberra, Australian Capital Territory, Australia
# Similarity Score: 0.5262
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Vivriti Capital
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5261
# -------------------------
# Job Title:
#
#         Data Scientist (Immediate Joiners only)
#
#
# Company:
#             Concentrix
#
# Location:
#             India
#
# Similarity Score: 0.5261
# -------------------------
# Job Title:
#
#         Data Scientist (Immediate Joiners only)
#
#
# Company:
#             Concentrix
#
# Location:
#             India
#
# Similarity Score: 0.5261
# -------------------------
# Job Title:
#
#         Lead Data Scientist
#
#
# Company:
#             IndusInd Bank
#
# Location:
#             Gurugram, Haryana, India
#
# Similarity Score: 0.5255
# -------------------------
# Job Title: Data Scientist
# Company: Matchtech
# Location: Preston, England, United Kingdom
# Similarity Score: 0.5254
# -------------------------
# Job Title:
#
#         Vice President of Human Resources
#
#
# Company:
#             Share India
#
# Location:
#             Noida, Uttar Pradesh, India
#
# Similarity Score: 0.5252
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             LTIMindtree
#
# Location:
#             Noida, Uttar Pradesh, India
#
# Similarity Score: 0.5251
# -------------------------
# Job Title:
#
#         Data Scientist -1
#
#
# Company:
#             SatSure
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5249
# -------------------------
# Job Title: Freelance Content Writer
# Company: Next Labs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5246
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             grofers
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5246
# -------------------------
# Job Title: Data Scientist, Growth & Analytics
# Company: Smile Identity
# Location: London, England, United Kingdom
# Similarity Score: 0.5246
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Acuity Knowledge Partners
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5245
# -------------------------
# Job Title: Content Writer
# Company: Qrata
# Location: Mumbai, Maharashtra, India
# Similarity Score: 0.5245
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             SatSure
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5243
# -------------------------
# Job Title: Content Writer
# Company: Qrata
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5243
# -------------------------
# Job Title:
#
#         Data Scientist - Machine Learning, Data Mining or Machine Intelligence
#
#
# Company:
#             Saint-Gobain Research India
#
# Location:
#             Chennai, Tamil Nadu, India
#
# Similarity Score: 0.5241
# -------------------------
# Job Title: Senior Research Analyst
# Company: GetMeResearch
# Location: Noida, Uttar Pradesh, India
# Similarity Score: 0.5241
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Capgemini
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5241
# -------------------------
# Job Title:
#
#         Data Scientist / Senior Data Scientist
#
#
# Company:
#             Boston Consulting Group (BCG)
#
# Location:
#             Delhi, India
#
# Similarity Score: 0.5241
# -------------------------
# Job Title: Product Analyst
# Company: Edulastic
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5239
# -------------------------
# Job Title:
#
#         Data Scientist - Remote (India)
#
#
# Company:
#             Aryng
#
# Location:
#             Kolkata, West Bengal, India
#
# Similarity Score: 0.5237
# -------------------------
# Job Title: Senior Product Engineer
# Company: Dunya Labs
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5237
# -------------------------
# Job Title: Senior Product Engineer
# Company: Dunya Labs
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5237
# -------------------------
# Job Title: Senior Product Engineer
# Company: Dunya Labs
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5237
# -------------------------
# Job Title: Senior Product Engineer
# Company: Dunya Labs
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5237
# -------------------------
# Job Title: Senior Product Engineer
# Company: Dunya Labs
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5237
# -------------------------
# Job Title: Senior Product Engineer
# Company: Dunya Labs
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5237
# -------------------------
# Job Title: Senior Product Engineer
# Company: Dunya Labs
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5237
# -------------------------
# Job Title: Senior Product Engineer
# Company: Dunya Labs
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5237
# -------------------------
# Job Title: Senior Product Engineer
# Company: Dunya Labs
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5237
# -------------------------
# Job Title: Data Scientist (HiTech, R&amp;D)
# Company: Ernest Gordon Recruitment
# Location: Workington, England, United Kingdom
# Similarity Score: 0.5236
# -------------------------
# Job Title: Data Scientist
# Company: Hook
# Location: London, England, United Kingdom
# Similarity Score: 0.5236
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Workplace Options
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5235
# -------------------------
# Job Title:
#
#         Executive - Back Office and Data Entry
#
#
# Company:
#             DC Consultants(India,USA,Australia,GCC)
#
# Location:
#             Navi Mumbai, Maharashtra, India
#
# Similarity Score: 0.5234
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Optimum Data Analytics
#
# Location:
#             Pune, Maharashtra, India
#
# Similarity Score: 0.5234
# -------------------------
# Job Title: Research Analyst
# Company: Antier Solutions
# Location: Sahibzada Ajit Singh Nagar, Punjab, India
# Similarity Score: 0.5233
# -------------------------
# Job Title:
#
#         Data Scientist_Roji_Remote
#
#
# Company:
#             CodersBrain
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5233
# -------------------------
# Job Title:
#
#         Software Tester
#
#
# Company:
#             GlobalShiksha.com
#
# Location:
#             Bengaluru North, Karnataka, India
#
# Similarity Score: 0.5232
# -------------------------
# Job Title:
#
#         Applied Data Scientist
#
#
# Company:
#             dunnhumby
#
# Location:
#             Gurgaon, Haryana, India
#
# Similarity Score: 0.5232
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Denave
#
# Location:
#             Noida, Uttar Pradesh, India
#
# Similarity Score: 0.5231
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Akaike Technologies
#
# Location:
#             Greater Bengaluru Area
#
# Similarity Score: 0.5230
# -------------------------
# Job Title: Frontend Developer
# Company: 99Yellow
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5230
# -------------------------
# Job Title: Frontend Developer
# Company: 99Yellow
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5230
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             NI (National Instruments)
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5227
# -------------------------
# Job Title:
#
#         Executive - Back Office and Data Entry
#
#
# Company:
#             DC Consultants(India,USA,Australia,GCC)
#
# Location:
#             Navi Mumbai, Maharashtra, India
#
# Similarity Score: 0.5226
# -------------------------
# Job Title:
#
#         Executive - Back Office and Data Entry
#
#
# Company:
#             DC Consultants(India,USA,Australia,GCC)
#
# Location:
#             Navi Mumbai, Maharashtra, India
#
# Similarity Score: 0.5226
# -------------------------
# Job Title:
#
#         Data Scientist_NLP_3-9 years
#
#
# Company:
#             Fractal
#
# Location:
#             Bangalore Urban, Karnataka, India
#
# Similarity Score: 0.5226
# -------------------------
# Job Title: Research Analyst II
# Company: S&P Global
# Location: Noida, Uttar Pradesh, India
# Similarity Score: 0.5225
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Response Informatics
#
# Location:
#             Delhi, India
#
# Similarity Score: 0.5221
# -------------------------
# Job Title: Senior DevOps Engineer
# Company: Web3Auth
# Location: Akuhaito, Nagaland, India
# Similarity Score: 0.5219
# -------------------------
# Job Title: Senior DevOps Engineer
# Company: Web3Auth
# Location: Akuhaito, Nagaland, India
# Similarity Score: 0.5219
# -------------------------
# Job Title: Senior DevOps Engineer
# Company: Web3Auth
# Location: Akuhaito, Nagaland, India
# Similarity Score: 0.5219
# -------------------------
# Job Title: Senior DevOps Engineer
# Company: Web3Auth
# Location: Akuhaito, Nagaland, India
# Similarity Score: 0.5219
# -------------------------
# Job Title: Senior DevOps Engineer
# Company: Web3Auth
# Location: Akuhaito, Nagaland, India
# Similarity Score: 0.5219
# -------------------------
# Job Title:
#
#         HR Assistant
#
#
# Company:
#             Owens Career Center
#
# Location:
#             Thane, Maharashtra, India
#
# Similarity Score: 0.5218
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             grofers
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5217
# -------------------------
# Job Title: full stack(react js node js)-kripa-accion labs
# Company: CodersBrain
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5214
# -------------------------
# Job Title: full stack(react js node js)-kripa-accion labs
# Company: CodersBrain
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5214
# -------------------------
# Job Title: full stack(react js node js)-kripa-accion labs
# Company: CodersBrain
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5214
# -------------------------
# Job Title: full stack(react js node js)-kripa-accion labs
# Company: CodersBrain
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5214
# -------------------------
# Job Title: full stack(react js node js)-kripa-accion labs
# Company: CodersBrain
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5214
# -------------------------
# Job Title: full stack(react js node js)-kripa-accion labs
# Company: CodersBrain
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5214
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             SatSure
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5212
# -------------------------
# Job Title:
#
#         Data Scientist - 2 (Gaming)
#
#
# Company:
#             Audify
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5209
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Workplace Options
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5208
# -------------------------
# Job Title: Research Analyst
# Company: Virtue Insight
# Location: Chennai, Tamil Nadu, India
# Similarity Score: 0.5207
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Impetus
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5207
# -------------------------
# Job Title: Content writer / Copy writer
# Company: Zigsaw
# Location: Mumbai, Maharashtra, India
# Similarity Score: 0.5207
# -------------------------
# Job Title: Senior Front-End Engineer (India)
# Company: Persistence Labs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5207
# -------------------------
# Job Title: Senior Front-End Engineer (India)
# Company: Persistence Labs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5207
# -------------------------
# Job Title: Senior Front-End Engineer (India)
# Company: Persistence Labs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5207
# -------------------------
# Job Title: Senior Front-End Engineer (India)
# Company: Persistence Labs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5207
# -------------------------
# Job Title: Senior Front-End Engineer (India)
# Company: Persistence Labs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5207
# -------------------------
# Job Title: Senior Front-End Engineer (India)
# Company: Persistence Labs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5207
# -------------------------
# Job Title: Senior Front-End Engineer (India)
# Company: Persistence Labs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5207
# -------------------------
# Job Title: Senior Front-End Engineer (India)
# Company: Persistence Labs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5207
# -------------------------
# Job Title: Senior Front-End Engineer (India)
# Company: Persistence Labs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5207
# -------------------------
# Job Title: Senior Front-End Engineer (India)
# Company: Persistence Labs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5207
# -------------------------
# Job Title:
#
#         Python Data scientist
#
#
# Company:
#             Antal International
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5206
# -------------------------
# Job Title: Senior Solidity Engineer (India)
# Company: Persistence Labs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5204
# -------------------------
# Job Title: Senior Solidity Engineer (India)
# Company: Persistence Labs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5204
# -------------------------
# Job Title: Senior Solidity Engineer (India)
# Company: Persistence Labs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5204
# -------------------------
# Job Title: Senior Solidity Engineer (India)
# Company: Persistence Labs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5204
# -------------------------
# Job Title: Senior Solidity Engineer (India)
# Company: Persistence Labs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5204
# -------------------------
# Job Title: Senior Solidity Engineer (India)
# Company: Persistence Labs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5204
# -------------------------
# Job Title: Senior Solidity Engineer (India)
# Company: Persistence Labs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5204
# -------------------------
# Job Title: Senior Solidity Engineer (India)
# Company: Persistence Labs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5204
# -------------------------
# Job Title: Senior Solidity Engineer (India)
# Company: Persistence Labs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5204
# -------------------------
# Job Title: Senior Solidity Engineer (India)
# Company: Persistence Labs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5204
# -------------------------
# Job Title: Consultant, Research
# Company: Sattva Consulting
# Location: Gurugram, Haryana, India
# Similarity Score: 0.5203
# -------------------------
# Job Title:
#
#         Software Engineer I (Java, Go, C and C++, Delphi, SQL, JavaScript Frameworks (Knockout, Angular, etc.))
#
#
# Company:
#             PDI Technologies
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5200
# -------------------------
# Job Title:
#
#         Learning, Development, and HR Administrator
#
#
# Company:
#             TraceLink
#
# Location:
#             Pune, Maharashtra, India
#
# Similarity Score: 0.5200
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             _VOIS
#
# Location:
#             Pune, Maharashtra, India
#
# Similarity Score: 0.5197
# -------------------------
# Job Title: Software Engineer
# Company: mquotient
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5196
# -------------------------
# Job Title: Software Engineer
# Company: mquotient
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5196
# -------------------------
# Job Title: Software Engineer
# Company: mquotient
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5196
# -------------------------
# Job Title: Software Engineer
# Company: mquotient
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5196
# -------------------------
# Job Title: Software Engineer
# Company: mquotient
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5196
# -------------------------
# Job Title: Software Engineer
# Company: mquotient
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5196
# -------------------------
# Job Title: Software Engineer
# Company: mquotient
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5196
# -------------------------
# Job Title: Software Engineer
# Company: mquotient
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5196
# -------------------------
# Job Title: Software Engineer
# Company: mquotient
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5196
# -------------------------
# Job Title: Software Engineer
# Company: mquotient
# ...
# Company: Global Talent Exchange
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5042
# -------------------------
# Job Title: Senior Solidity Engineer-Return to INDIA
# Company: Global Talent Exchange
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5042
# -------------------------
# Job Title: Senior Solidity Engineer-Return to INDIA
# Company: Global Talent Exchange
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5042
# -------------------------
# Job Title: Senior Solidity Engineer-Return to INDIA
# Company: Global Talent Exchange
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5042
# -------------------------
# Job Title: Senior Solidity Engineer-Return to INDIA
# Company: Global Talent Exchange
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5042
# -------------------------
# Job Title: Senior Solidity Engineer-Return to INDIA
# Company: Global Talent Exchange
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5042
# -------------------------
# Job Title:
#
#         Graphic Designer
#
#
# Company:
#             WiseBee Consultants
#
# Location:
#             Mumbai, Maharashtra, India
#
# Similarity Score: 0.5040
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Concentrix
#
# Location:
#             Gurugram, Haryana, India
#
# Similarity Score: 0.5039
# -------------------------
# Job Title:
#
#         Python Developer
#
#
# Company:
#             Hyrhub
#
# Location:
#             Mumbai, Maharashtra, India
#
# Similarity Score: 0.5037
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             ITC Infotech
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5037
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             SatSure
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5036
# -------------------------
# Job Title: Data Scientist
# Company: Targetcost Realty LLC
# Location: Basingstoke, England, United Kingdom
# Similarity Score: 0.5034
# -------------------------
# Job Title: Analyst - Learning Operations
# Company: DIAGEO India
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5032
# -------------------------
# Job Title:
#
#         Data Scientist / Senior Data Scientist
#
#
# Company:
#             Boston Consulting Group (BCG)
#
# Location:
#             Delhi, India
#
# Similarity Score: 0.5031
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             GreyB
#
# Location:
#             Chandigarh, India
#
# Similarity Score: 0.5030
# -------------------------
# Job Title:
#
#         Administrative Assistant
#
#
# Company:
#             BPM LLP
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5030
# -------------------------
# Job Title: Research Analyst
# Company: HVantage Technologies Inc USA
# Location: Indore, Madhya Pradesh, India
# Similarity Score: 0.5029
# -------------------------
# Job Title: Software Development Engineer - 1 (Back-end)
# Company: Yo Hr Consultancy
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5029
# -------------------------
# Job Title: Software Development Engineer - 1 (Back-end)
# Company: Yo Hr Consultancy
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5029
# -------------------------
# Job Title: Software Development Engineer - 1 (Back-end)
# Company: Yo Hr Consultancy
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5029
# -------------------------
# Job Title: Software Development Engineer - 1 (Back-end)
# Company: Yo Hr Consultancy
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5029
# -------------------------
# Job Title: Software Development Engineer - 1 (Back-end)
# Company: Yo Hr Consultancy
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5029
# -------------------------
# Job Title: Software Development Engineer - 1 (Back-end)
# Company: Yo Hr Consultancy
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5029
# -------------------------
# Job Title: Software Development Engineer - 1 (Back-end)
# Company: Yo Hr Consultancy
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5029
# -------------------------
# Job Title: Software Development Engineer - 1 (Back-end)
# Company: Yo Hr Consultancy
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5029
# -------------------------
# Job Title: Software Development Engineer - 1 (Back-end)
# Company: Yo Hr Consultancy
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5029
# -------------------------
# Job Title: Software Development Engineer - 1 (Back-end)
# Company: Yo Hr Consultancy
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5029
# -------------------------
# Job Title:
#
#         Software Developer
#
#
# Company:
#             EqualizeRCM
#
# Location:
#             Mysore, Karnataka, India
#
# Similarity Score: 0.5028
# -------------------------
# Job Title: Senior Data Scientist
# Company: LVT People
# Location: Sydney, New South Wales, Australia
# Similarity Score: 0.5027
# -------------------------
# Job Title: Senior Data Scientist
# Company: LVT People
# Location: Sydney, New South Wales, Australia
# Similarity Score: 0.5027
# -------------------------
# Job Title: Senior Data Scientist
# Company: LVT People
# Location: Sydney, New South Wales, Australia
# Similarity Score: 0.5027
# -------------------------
# Job Title: Senior Data Scientist
# Company: LVT People
# Location: Sydney, New South Wales, Australia
# Similarity Score: 0.5027
# -------------------------
# Job Title: Data Scientist
# Company: Systems Planning and Analysis, Inc.
# Location: Canberra, Australian Capital Territory, Australia
# Similarity Score: 0.5026
# -------------------------
# Job Title: Data Scientist
# Company: Systems Planning and Analysis, Inc.
# Location: Canberra, Australian Capital Territory, Australia
# Similarity Score: 0.5026
# -------------------------
# Job Title: Data Scientist
# Company: Systems Planning and Analysis, Inc.
# Location: Canberra, Australian Capital Territory, Australia
# Similarity Score: 0.5026
# -------------------------
# Job Title: Data Scientist
# Company: Systems Planning and Analysis, Inc.
# Location: Canberra, Australian Capital Territory, Australia
# Similarity Score: 0.5026
# -------------------------
# Job Title:
#
#         Data Scientist - 2 (Gaming)
#
#
# Company:
#             Audify
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5025
# -------------------------
# Job Title:
#
#         Lead Data Scientist
#
#
# Company:
#             IndusInd Bank
#
# Location:
#             Gurugram, Haryana, India
#
# Similarity Score: 0.5025
# -------------------------
# Job Title:
#
#         Data Scientist_NLP_3-9 years
#
#
# Company:
#             Fractal
#
# Location:
#             Bangalore Urban, Karnataka, India
#
# Similarity Score: 0.5025
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Wrackle
#
# Location:
#             Bengaluru North, Karnataka, India
#
# Similarity Score: 0.5025
# -------------------------
# Job Title: Data Scientist (Hybrid in-office/remote)
# Company: S&P Global
# Location: London, England, United Kingdom
# Similarity Score: 0.5024
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Qcentrio
#
# Location:
#             Coimbatore, Tamil Nadu, India
#
# Similarity Score: 0.5022
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             TVS Next
#
# Location:
#             Chennai, Tamil Nadu, India
#
# Similarity Score: 0.5021
# -------------------------
# Job Title:
#
#         Software Development Engineer- Full Stack
#
#
# Company:
#             Zoom
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5021
# -------------------------
# Job Title: Pragmatic Business Development Researcher  - India
# Company: Laminar Projects
# Location: India
# Similarity Score: 0.5020
# -------------------------
# Job Title: Full Stack Developer
# Company: Fitbots OKRs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5020
# -------------------------
# Job Title: Full Stack Developer
# Company: Fitbots OKRs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5020
# -------------------------
# Job Title: Full Stack Developer
# Company: Fitbots OKRs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5020
# -------------------------
# Job Title: Full Stack Developer
# Company: Fitbots OKRs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5020
# -------------------------
# Job Title: Full Stack Developer
# Company: Fitbots OKRs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5020
# -------------------------
# Job Title: Full Stack Developer
# Company: Fitbots OKRs
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5020
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Vivriti Capital
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5019
# -------------------------
# Job Title:
#
#         Data Scientist 2
#
#
# Company:
#             Epsilon India
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5018
# -------------------------
# Job Title: Expression of Interest: Data Scientist
# Company: Fingerprint for Success (F4S)
# Location: Australia
# Similarity Score: 0.5018
# -------------------------
# Job Title: Full Stack Laravel Developer
# Company: Toolyt
# Location: Bengaluru, Karnataka, India
# Similarity Score: 0.5018
# -------------------------
# Job Title: Senior Research Analyst/Associate - Market Intelligence/Research
# Company: Talent Acceleration Corridor (TA Corridor)
# Location: Noida, Uttar Pradesh, India
# Similarity Score: 0.5017
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Valiance Solutions
#
# Location:
#             Bangalore Urban, Karnataka, India
#
# Similarity Score: 0.5017
# -------------------------
# Job Title:
#
#         Data Scientist-II
#
#
# Company:
#             General Mills India
#
# Location:
#             Mumbai, Maharashtra, India
#
# Similarity Score: 0.5017
# -------------------------
# Job Title: Lead Data Scientist
# Company: Correlate Resources
# Location: Melbourne, Victoria, Australia
# Similarity Score: 0.5017
# -------------------------
# Job Title: Technical Script Writer
# Company: Harvest Talent Recruitment & People Solutions
# Location: Geelong, Victoria, Australia
# Similarity Score: 0.5016
# -------------------------
# Job Title:
#
#         Jr. Software Developer
#
#
# Company:
#             SlashRTC
#
# Location:
#             Mumbai, Maharashtra, India
#
# Similarity Score: 0.5015
# -------------------------
# Job Title:
#
#         Vice President Human Resources
#
#
# Company:
#             True Blue HR Consultants
#
# Location:
#             Hospet, Karnataka, India
#
# Similarity Score: 0.5015
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             OneLabs
#
# Location:
#             Delhi, Delhi, India
#
# Similarity Score: 0.5013
# -------------------------
# Job Title:
#
#         Data Scientist I
#
#
# Company:
#             Chegg India
#
# Location:
#             Delhi, Delhi, India
#
# Similarity Score: 0.5012
# -------------------------
# Job Title: Configuration Engineer
# Company: Signzy
# Location: Bengaluru North, Karnataka, India
# Similarity Score: 0.5012
# -------------------------
# Job Title: Tactical and Analytics Engineer (Data Scientist)
# Company: SA Water
# Location: Adelaide, South Australia, Australia
# Similarity Score: 0.5012
# -------------------------
# Job Title: Tactical and Analytics Engineer (Data Scientist)
# Company: SA Water
# Location: Adelaide, South Australia, Australia
# Similarity Score: 0.5012
# -------------------------
# Job Title: Tactical and Analytics Engineer (Data Scientist)
# Company: SA Water
# Location: Adelaide, South Australia, Australia
# Similarity Score: 0.5012
# -------------------------
# Job Title: Tactical and Analytics Engineer (Data Scientist)
# Company: SA Water
# Location: Adelaide, South Australia, Australia
# Similarity Score: 0.5012
# -------------------------
# Job Title:
#
#         HR Manager
#
#
# Company:
#             RUDR Consultancy Services
#
# Location:
#             Udaipur, Rajasthan, India
#
# Similarity Score: 0.5011
# -------------------------
# Job Title:
#
#         Vice President Human Resources
#
#
# Company:
#             True Blue HR Consultants
#
# Location:
#             Hospet, Karnataka, India
#
# Similarity Score: 0.5011
# -------------------------
# Job Title:
#
#         Driver / Office Assistant
#
#
# Company:
#             Australian Trade and Investment Commission (Austrade)
#
# Location:
#             Bangalore Urban, Karnataka, India
#
# Similarity Score: 0.5009
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Xceedance
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5009
# -------------------------
# Job Title:
#
#         Software Developer
#
#
# Company:
#             EqualizeRCM
#
# Location:
#             Mysore, Karnataka, India
#
# Similarity Score: 0.5008
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             Valiance Solutions
#
# Location:
#             Bangalore Urban, Karnataka, India
#
# Similarity Score: 0.5004
# -------------------------
# Job Title:
#
#         React Engineer
#
#
# Company:
#             Vichara Technologies
#
# Location:
#             Gurugram, Haryana, India
#
# Similarity Score: 0.5004
# -------------------------
# Job Title:
#
#         Data Scientist - Consulting Firm
#
#
# Company:
#             RedBox HR Consulting
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5004
# -------------------------
# Job Title:
#
#         Data Scientist
#
#
# Company:
#             PayPal
#
# Location:
#             Tondiarpet, Tamil Nadu, India
#
# Similarity Score: 0.5003
# -------------------------
# Job Title: Decision Science Modelling - Senior Analyst
# Company: Datatech Analytics
# Location: London Area, United Kingdom
# Similarity Score: 0.5002
# -------------------------
# Job Title:
#
#         Administrative Assistant
#
#
# Company:
#             NAVIS Human Resources
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5002
# -------------------------
# Job Title:
#
#         Administrative Assistant
#
#
# Company:
#             NAVIS Human Resources
#
# Location:
#             Bengaluru, Karnataka, India
#
# Similarity Score: 0.5002
# -------------------------
# Job Title: Data Scientist
# Company: Understanding Recruitment
# Location: London, England, United Kingdom
# Similarity Score: 0.5001
# -------------------------
# No results found.
# Enter your query (or 'exit' to quit):  exit
# Exiting...
